# %% [markdown]
# <a href="https://colab.research.google.com/github/ChapelFob80930/Retail-Recommender-System/blob/main/retail_recommender_system_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy
print(numpy.__version__)
# Out:
# 2.0.2

# %%
df = pd.read_excel("/content/drive/MyDrive/online_retail_II.xlsx")

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
df.shape
# Out:
# (525461, 8)

# %%
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
df['Total Price'] = df['Quantity'] * df['Price']

# %%
preprocessed_dataset = df[df['Total Price'] > 0].copy()

# %%
# preprocessed_dataset = preprocessed_dataset.loc[preprocessed_dataset['Quantity'] > 0]

# %%
preprocessed_dataset
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country  Total Price
# ...

# %%
index_of_row = df[df['Total Price'] == 15818.4].index
print("Index where Total Price is 15818.4:", index_of_row)
# Out:
# Index where Total Price is 15818.4: Index([432176], dtype='int64')

# %%
preprocessed_dataset.loc[preprocessed_dataset['Total Price'] == 15818.4]
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 432176  530715     84347  ROTATING SILVER ANGELS T-LIGHT HLDR      9360
#
#                InvoiceDate  Price  Customer ID         Country  Total Price
# 432176 2010-11-04 11:36:00   1.69      15838.0  United Kingdom      15818.4

# %%
preprocessed_dataset.shape
# Out:
# (511566, 9)

# %%
preprocessed_dataset.isna().sum()
# Out:
# Invoice             0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    103902
# Country             0
# Total Price         0
# dtype: int64

# %%
preprocessed_dataset = preprocessed_dataset.dropna(subset=['Customer ID', 'StockCode', 'Total Price'])

# %%
preprocessed_dataset.isna().sum()
# Out:
# Invoice        0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# Price          0
# Customer ID    0
# Country        0
# Total Price    0
# dtype: int64

# %%
preprocessed_dataset.shape
# Out:
# (407664, 9)

# %%
preprocessed_dataset
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country  Total Price
# ...

# %%
customer_item_matrix = preprocessed_dataset.pivot_table(index='Customer ID', columns='StockCode', values='Total Price', aggfunc='sum')

# %%
print(customer_item_matrix.head())
# Out:
# StockCode    10002  10080  10109  10120  10125  10133  10134  10135  10138  \
# Customer ID
# 12346.0        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 12347.0        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 12348.0        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 12349.0        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 12351.0        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# StockCode    11001  ...  ADJUST2  BANK CHARGES  C2   D   M  PADS   POST  \
# Customer ID         ...
# 12346.0        NaN  ...      NaN           NaN NaN NaN NaN   NaN    NaN
# 12347.0        NaN  ...      NaN           NaN NaN NaN NaN   NaN    NaN
# 12348.0        NaN  ...      NaN           NaN NaN NaN NaN   NaN    1.0
# 12349.0        NaN  ...      NaN           NaN NaN NaN NaN   NaN  450.0
# 12351.0        NaN  ...      NaN           NaN NaN NaN NaN   NaN    NaN
#
# StockCode    SP1002  TEST001  TEST002
# ...

# %%
print(preprocessed_dataset['Total Price'].min())
print(preprocessed_dataset['Total Price'].max())
# Out:
# 0.001
# 15818.4

# %%
backup = preprocessed_dataset

# %%
# preprocessed_dataset = preprocessed_dataset[preprocessed_dataset['Total Price'] > 0]

# %%
# Find rows where Total Price is exactly 0
zero_values = preprocessed_dataset[preprocessed_dataset['Total Price'] == 0]
print(f"Number of zero values: {len(zero_values)}")
print(zero_values)
# Out:
# Number of zero values: 0
# Empty DataFrame
# Columns: [Invoice, StockCode, Description, Quantity, InvoiceDate, Price, Customer ID, Country, Total Price]
# Index: []

# %%
# Find rows where Total Price is negative
negative_values = preprocessed_dataset[preprocessed_dataset['Total Price'] < 0]
print(f"Number of negative values: {len(negative_values)}")
print(negative_values)
# Out:
# Number of negative values: 0
# Empty DataFrame
# Columns: [Invoice, StockCode, Description, Quantity, InvoiceDate, Price, Customer ID, Country, Total Price]
# Index: []

# %%
preprocessed_dataset['Normalized Price'] = (
    5 * (preprocessed_dataset['Total Price'] - preprocessed_dataset['Total Price'].min()) /
    (preprocessed_dataset['Total Price'].max() - preprocessed_dataset['Total Price'].min())
)
# Out:
# <ipython-input-23-422de52ebb47>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preprocessed_dataset['Normalized Price'] = (

# %%
import numpy as np

preprocessed_dataset['Log Price'] = np.log1p(preprocessed_dataset['Total Price'])
# Out:
# <ipython-input-24-86eb064937b2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preprocessed_dataset['Log Price'] = np.log1p(preprocessed_dataset['Total Price'])

# %%
preprocessed_dataset['Log Price'] = 5 * (preprocessed_dataset['Log Price'] - preprocessed_dataset['Log Price'].min()) / (preprocessed_dataset['Log Price'].max() - preprocessed_dataset['Log Price'].min())
# Out:
# <ipython-input-25-b98eeb062774>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preprocessed_dataset['Log Price'] = 5 * (preprocessed_dataset['Log Price'] - preprocessed_dataset['Log Price'].min()) / (preprocessed_dataset['Log Price'].max() - preprocessed_dataset['Log Price'].min())

# %%
preprocessed_dataset
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country  Total Price  \
# ...

# %%
# Check if there are any negative or zero values left
invalid_rows = preprocessed_dataset[(preprocessed_dataset['Total Price'] <= 0)]
print(f"Remaining invalid rows: {len(invalid_rows)}")  # Should be 0
# Out:
# Remaining invalid rows: 0

# %%
# !pip install surprise

# %%
# from surprise import SVD, Reader, Dataset
# from surprise.model_selection import train_test_split
# from surprise import accuracy

# reader = Reader(rating_scale=(preprocessed_dataset['Total Price'].min(), preprocessed_dataset['Total Price'].max()))
# data = Dataset.load_from_df(preprocessed_dataset[['Customer ID', 'StockCode', 'Total Price']], reader)

# %%
# import numpy as np

# %%
# !pip uninstall numpy
# Out:
# Found existing installation: numpy 2.0.2
# Uninstalling numpy-2.0.2:
#   Would remove:
#     /usr/local/bin/f2py
#     /usr/local/bin/numpy-config
#     /usr/local/lib/python3.11/dist-packages/numpy-2.0.2.dist-info/*
#     /usr/local/lib/python3.11/dist-packages/numpy.libs/libgfortran-040039e1-0352e75f.so.5.0.0
#     /usr/local/lib/python3.11/dist-packages/numpy.libs/libquadmath-96973f99-934c22de.so.0.0.0
#     /usr/local/lib/python3.11/dist-packages/numpy.libs/libscipy_openblas64_-99b71e71.so
#     /usr/local/lib/python3.11/dist-packages/numpy/*
# Proceed (Y/n)? y
#   Successfully uninstalled numpy-2.0.2

# %%
# !pip install numpy==1.26.0 # or any version < 2.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 74.4 MB/s eta 0:00:00
# ...

# %%
# from surprise import SVD, Reader, Dataset
# from surprise.model_selection import train_test_split
# from surprise import accuracy

# reader = Reader(rating_scale=(preprocessed_dataset['Normalized Price'].min(), preprocessed_dataset['Normalized Price'].max()))
# data = Dataset.load_from_df(preprocessed_dataset[['Customer ID', 'StockCode', 'Normalized Price']], reader)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
# ...

# %%
preprocessed_dataset['Normalized Price'].max()
# Out:
# 5.0

# %%
# from surprise import SVD, Reader, Dataset
# from surprise.model_selection import train_test_split
# from surprise import accuracy

# reader = Reader(rating_scale=(0, 5))
# data = Dataset.load_from_df(preprocessed_dataset[['Customer ID', 'StockCode', 'Normalized Price']], reader)

# %%
# from surprise import SVD, Reader, Dataset
# from surprise.model_selection import train_test_split
# from surprise import accuracy

# reader = Reader(rating_scale=(preprocessed_dataset['Log Price'].min(), preprocessed_dataset['Log Price'].max()))
# data = Dataset.load_from_df(preprocessed_dataset[['Customer ID', 'StockCode', 'Log Price']], reader)

# %%
from surprise import SVD, Reader, Dataset
from surprise.model_selection import train_test_split
from surprise import accuracy

reader = Reader(rating_scale=(0, 5))
data = Dataset.load_from_df(preprocessed_dataset[['Customer ID', 'StockCode', 'Log Price']], reader)

# %%
trainset = data.build_full_trainset()
print("Sample of training data:")
for uid, iid, true_r in trainset.all_ratings():
  if(true_r == 0 or true_r < 0):
    print(f"Customer ID: {uid}, StockCode: {iid}, Total Price: {true_r}")
# Out:
# Sample of training data:
# Customer ID: 82, StockCode: 2892, Total Price: 0.0
# Customer ID: 282, StockCode: 2892, Total Price: 0.0
# Customer ID: 282, StockCode: 2892, Total Price: 0.0
# Customer ID: 586, StockCode: 2892, Total Price: 0.0
# Customer ID: 708, StockCode: 2892, Total Price: 0.0
# Customer ID: 1308, StockCode: 2892, Total Price: 0.0
# Customer ID: 1309, StockCode: 2892, Total Price: 0.0
# Customer ID: 1354, StockCode: 2892, Total Price: 0.0
# Customer ID: 1614, StockCode: 2892, Total Price: 0.0
# Customer ID: 1614, StockCode: 2892, Total Price: 0.0
# Customer ID: 1665, StockCode: 2892, Total Price: 0.0
# Customer ID: 1698, StockCode: 2892, Total Price: 0.0
# Customer ID: 1909, StockCode: 2892, Total Price: 0.0
# Customer ID: 2253, StockCode: 2892, Total Price: 0.0

# %%
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

# %%
# from surprise.model_selection import GridSearchCV

# param_grid = {
#     'n_factors': [50, 100, 150],
#     'n_epochs': [20, 30],
#     'lr_all': [0.002, 0.005],
#     'reg_all': [0.02, 0.1]
# }


# grid_search_normal_data = GridSearchCV(SVD, param_grid, measures=['rmse'], cv=3)
# grid_search_normal_data.fit(data)


# print(f"Best RMSE: {grid_search_normal_data.best_score['rmse']}")
# print(f"Best parameters: {grid_search_normal_data.best_params['rmse']}")


# best_model_SVD_normal_data = grid_search_normal_data.best_estimator['rmse']
# best_model_SVD_normal_data.fit(trainset)
# predictions = best_model_SVD_normal_data.test(testset)


# rmse = accuracy.rmse(predictions)
# print(f"RMSE on Test Set: {rmse}")

# mae = accuracy.mae(predictions)
# print(f"MAE on Test Set: {mae}")
# Out:
# Best RMSE: 15796.906257014503
# Best parameters: {'n_factors': 50, 'n_epochs': 20, 'lr_all': 0.002, 'reg_all': 0.02}
# RMSE: 15796.9253
# RMSE on Test Set: 15796.92526443298

# %%
# from surprise.model_selection import GridSearchCV

# param_grid = {
#     'n_factors': [50, 100, 150],
#     'n_epochs': [20, 30],
#     'lr_all': [0.002, 0.005],
#     'reg_all': [0.02, 0.1]
# }


# grid_search_normalized_data = GridSearchCV(SVD, param_grid, measures=['rmse'], cv=3)
# grid_search_normalized_data.fit(data)


# print(f"Best RMSE: {grid_search_normalized_data.best_score['rmse']}")
# print(f"Best parameters: {grid_search_normalized_data.best_params['rmse']}")


# best_model_SVD_normalized_data = grid_search_normalized_data.best_estimator['rmse']
# best_model_SVD_normalized_data.fit(trainset)
# predictions = best_model_SVD_normalized_data.test(testset)


# rmse = accuracy.rmse(predictions)
# print(f"RMSE on Test Set: {rmse}")

# mae = accuracy.mae(predictions)
# print(f"MAE on Test Set: {mae}")
# Out:
# Best RMSE: 0.021244610414384097
# Best parameters: {'n_factors': 50, 'n_epochs': 30, 'lr_all': 0.005, 'reg_all': 0.1}
# RMSE: 0.0200
# RMSE on Test Set: 0.01997536249423915
# MAE:  0.0051
# MAE on Test Set: 0.005138448798207271

# %%
from surprise.model_selection import GridSearchCV

param_grid = {
    'n_factors': [50, 100, 150],
    'n_epochs': [20, 30],
    'lr_all': [0.002, 0.005],
    'reg_all': [0.02, 0.1]
}


grid_search_log_data = GridSearchCV(SVD, param_grid, measures=['rmse'], cv=3)
grid_search_log_data.fit(data)


print(f"Best RMSE: {grid_search_log_data.best_score['rmse']}")
print(f"Best parameters: {grid_search_log_data.best_params['rmse']}")


best_model_SVD_log_data = grid_search_log_data.best_estimator['rmse']
best_model_SVD_log_data.fit(trainset)
predictions = best_model_SVD_log_data.test(testset)


rmse = accuracy.rmse(predictions)
print(f"RMSE on Test Set: {rmse}")

mae = accuracy.mae(predictions)
print(f"MAE on Test Set: {mae}")
# Out:
# Best RMSE: 0.2926219634851606
# Best parameters: {'n_factors': 150, 'n_epochs': 30, 'lr_all': 0.005, 'reg_all': 0.02}
# RMSE: 0.2873
# RMSE on Test Set: 0.2873182821157488
# MAE:  0.2122
# MAE on Test Set: 0.21216650403500117

# %%
# from surprise import SVDpp, NMF


# svdpp_normal_data = SVDpp()

# svdpp_normal_data.fit(trainset)

# predictions_svdpp = svdpp.test(testset)

# rmse_svdpp = accuracy.rmse(predictions_svdpp)
# print(f"RMSE on Test Set for SVD++: {rmse_svdpp}")

# print(f"MAE on Test Set for SVD++: {accuracy.mae(predictions_svdpp)}")
# Out:
# RMSE: 15796.9253
# RMSE on Test Set for SVD++: 15796.92526443298

# %%
# from surprise import SVDpp, NMF


# svdpp_normalized_data = SVDpp()

# svdpp_normalized_data.fit(trainset)

# predictions_svdpp = svdpp.test(testset)

# rmse_svdpp = accuracy.rmse(predictions_svdpp)
# print(f"RMSE on Test Set for SVD++: {rmse_svdpp}")

# print(f"MAE on Test Set for SVD++: {accuracy.mae(predictions_svdpp)}")
# Out:
# RMSE: 15818.3931
# RMSE on Test Set for SVD++: 15818.393087446773
# MAE:  15818.3931
# MAE on Test Set for SVD++: 15818.393087428161

# %%
from surprise import SVDpp, NMF


svdpp_log_data = SVDpp()

svdpp_log_data.fit(trainset)

predictions_svdpp = svdpp.test(testset)

rmse_svdpp = accuracy.rmse(predictions_svdpp)
print(f"RMSE on Test Set for SVD++: {rmse_svdpp}")

print(f"MAE on Test Set for SVD++: {accuracy.mae(predictions_svdpp)}")
# Out:
# RMSE: 15817.1211
# RMSE on Test Set for SVD++: 15817.121108413281
# MAE:  15817.1211
# MAE on Test Set for SVD++: 15817.121099868591

# %%
# nmf_normal_data = NMF()

# nmf_normal_data.fit(trainset)

# predictions_nmf = nmf.test(testset)

# rmse_nmf = accuracy.rmse(predictions_nmf)
# print(f"RMSE on Test Set for NMF: {rmse_nmf}")

# print(f"MAE on Test Set for NMF: {accuracy.mae(predictions_nmf)}")
# Out:
# RMSE: 85.5708
# RMSE on Test Set for NMF: 85.5708416795781

# %%
# nmf_normalized_data = NMF()

# nmf_normalized_data.fit(trainset)

# predictions_nmf = nmf.test(testset)

# rmse_nmf = accuracy.rmse(predictions_nmf)
# print(f"RMSE on Test Set for NMF: {rmse_nmf}")

# print(f"MAE on Test Set for NMF: {accuracy.mae(predictions_nmf)}")
# Out:
# RMSE: 9.2935
# RMSE on Test Set for NMF: 9.293484004487023
# MAE:  3.0968
# MAE on Test Set for NMF: 3.0968248218441277

# %%
nmf_log_data = NMF()

nmf_log_data.fit(trainset)

predictions_nmf = nmf.test(testset)

rmse_nmf = accuracy.rmse(predictions_nmf)
print(f"RMSE on Test Set for NMF: {rmse_nmf}")

print(f"MAE on Test Set for NMF: {accuracy.mae(predictions_nmf)}")
# Out:
# RMSE: 8.7565
# RMSE on Test Set for NMF: 8.756537513812395
# MAE:  1.9853
# MAE on Test Set for NMF: 1.9852878283333215

# %%
def get_top_n(predictions, n=10):
    top_n = {}
    for uid, iid, true_r, est, _ in predictions:
        if uid not in top_n:
            top_n[uid] = []
        top_n[uid].append((iid, est))

    # Now sort the recommendations for each user
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

top_n_recommendations = get_top_n(predictions, n=5)
print(top_n_recommendations)
